# %% [markdown]
# frequency가 2 이상인 데이터 추출 순서
# 1. frequency가 2 이상인 단어 제외하고 다 삭제
# 2. hop_num 다시 계산한다. (null인 경우 0으로 처리)
# 3. 각 단어가 20개 이상인 데이터만 남겨두고 삭제

# %%
import pandas as pd
import json
import random

df = pd.read_excel("../../data/one_hop/preprocessed_df.xlsx")
df.fillna('null',inplace=True)
dx = df.copy()

with open('../../data/one_hop/word_frequency.json', "r") as f:
    word_counts = json.load(f)

# %%
df.head()
# Out:
#    index                          subject subject_id  \
# 0      0                Danielle Darrieux    Q234149
# 1      1             Edwin of Northumbria    Q348955
# 2      2                      Toko Yasuda   Q7813654
# 3      3  Autonomous University of Madrid    Q788091
# 4      4                             Lyon       Q456
#
#                                          sbj_one_hop  sbj_hop_num  \
# 0  human,film actor,Porfirio Rubirosa,Georges Mit...           20
# 1  Whitby Abbey,human,Catholic saint,Cwenburh,Ger...           11
# 2  Japan,human,plvsvltramusic,rock music,bass gui...           12
# 3  Coalition for Advancing Research Assessment,Ag...            8
# 4  FRLIO,Gallia Lugdunensis,Lionano,Vaise,Jericho...           37
#
#        obj_true obj_true_id  \
# 0        French        Q150
# 1  Christianity       Q5043
# 2        guitar       Q6607
# 3         Spain         Q29
# 4        Beirut       Q3820
#
#                                          obj_one_hop  obj_true_hop_num  \
# 0  Vietnam,past imperative,Mali,participle,syllab...                72
# 1  Bible,christianisme,Jesus,Christian,hiristiyan...                17
# 2  body,machine head,Gitarre,Armenian Soviet Ency...                28
# 3  La Rioja,Vietnam,Carlist Wars,Occitan,Immacula...               153
# 4  Lebanon,Mousseitbeh,Ashrafieh,administrative t...                39
#
#    obj_new obj_new_id                                    obj_new_one_hop  \
# 0  English      Q1860  simple present,Brunei,close back rounded vowel...
# 1    Islam       Q432  Battle of Uhud,Kaaba,Sufism,Dua,Jewish Encyclo...
# 2    piano      Q5994  klaver,Bartolomeo Cristofori,A,pianist,Klavier...
# 3   Sweden        Q34  Iran,Kattegat,suedezi,Halland,Iraq,Swedish Emp...
# 4   Manila      Q1461  Nice,Pearl of the Orient,Philippines,Sacrament...
#
#    obj_new_hop_num     view
# 0              149   222931
# 1               68   177019
# 2                6    74330
# 3              136    87615
# 4               82  2376138

# %%
for i in range(len(df)):
    if (df.loc[i, 'sbj_one_hop'] == 'null'):
        print(df.loc[i, 'index'],df.loc[i, 'subject'],",", df.loc[i, 'subject_id'], ",", df.loc[i, 'obj_true'],",", df.loc[i, 'obj_new'])
# Out:
# 25 Platform Controller Hub , Q2811910 , Intel , Dodge
# 51 Prydz Bay , Q156116 , Antarctica , Africa
# 118 Oliver Ames High School , Q7087388 , Massachusetts , Pennsylvania
# 125 Manila Light Rail Transit System , Q4165607 , Philippines , Ukraine
# 187 Hamburg International Film Festival , Q1414659 , Hamburg , Rome
# 208 Teres Ridge , Q7702080 , Antarctica , Africa
# 221 Risemedet Mountain , Q7335997 , Antarctica , Americas
# 281 Matusevich Glacier , Q6792020 , Antarctica , Europe
# 4163 A Ver-o-Mar , Q300608 , Portuguese , Finnish
# 4206 Beascochea Bay , Q141504 , Antarctica , Americas
# 4225 ColorSync , Q1111151 , Apple , Microsoft
# 4230 Atlantic Film Festival , Q125608819 , Halifax , Santiago
# 4306 Astrolabe Glacier , Q3108357 , Antarctica , Africa
# 4413 Hull Glacier , Q5935916 , Antarctica , Europe
# 4434 Wapekeka First Nation , Q7968241 , Ontario , Berkshire
# 4511 KaraFilm Festival , Q6367512 , Karachi , Barcelona
# 4519 Shinnan Glacier , Q3108323 , Antarctica , Europe
# 4526 Al-Suqaylabiyah Subdistrict , Q12247301 , Syria , India
# 4527 English plural , Q5378621 , English , German
# 4532 Event Viewer , Q360204 , Microsoft , IBM
# 4544 William Scoresby Bay , Q156132 , Antarctica , Europe
# 4612 Java coffee , Q2642722 , Java , Amsterdam
# 4693 Bruce Plateau , Q4978145 , Antarctica , Asia
# 4766 Loy Yang Power Station , Q1165095 , Victoria , Queensland
# 4816 Nokia Internet tablet , Q6267970 , Nokia , Intel
# 4858 Microsoft Expression Blend , Q594763 , Microsoft , Apple
# 4869 Kadrina Rural Municipality , Q1013773 , Estonia , Argentina
# 4872 Alberta Alliance Party , Q4711576 , Canada , Argentina
# 4939 Northeast Glacier , Q8964182 , Antarctica , Europe
# 4967 A Marriage Proposal , Q1194195 , Russian , Hebrew
# 4985 Prespa Glacier , Q7241579 , Antarctica , Europe
# 4986 Romania during World War I , Q85808346 , Romania , London
# 5014 Vestreskorve Glacier , Q7923502 , Antarctica , Asia
# 5086 Shipka Saddle , Q7498002 , Antarctica , Europe
# 5115 IBM Rational Unified Process , Q478019 , IBM , Nintendo
# 5129 Portobello Film Festival , Q966765 , London , Philadelphia
# 5146 Garwood Valley , Q5524553 , Antarctica , Europe
# 5230 Constitution of Afghanistan , Q2545548 , Afghanistan , Venezuela
# 5279 Varna Peninsula , Q2646658 , Antarctica , Asia
# 5300 Sony SLT camera , Q209491 , Sony , Fiat
# 5312 Forster Square , Q5470629 , Bradford , Rome
# 5372 Mount Weaver , Q6924529 , Antarctica , Asia
# 5399 Edmonton International Film Festival , Q5339068 , Edmonton , Yorkshire
# 5432 Cuban War of Independence , Q1514908 , Cuba , Hungary
# 5434 Beaglehole Glacier , Q4876097 , Antarctica , Americas
# 5440 Southampton Castle , Q7569104 , Southampton , Alberta
# 5444 Vietnam Film Festival , Q7928507 , Vietnam , Moscow
# 5514 IBM 1710 , Q5965596 , IBM , Dodge
# 5654 Von Essen Mountain , Q7756724 , Antarctica , Asia
# 5676 Spicket River , Q7576951 , Massachusetts , Independence
# 5770 Russians in Ukraine , Q311762 , Russian , French
# 5873 Norwich Market , Q3289887 , Norwich , Irvine
# 5914 Schytt Glacier , Q3372454 , Antarctica , Europe
# 5926 Achaean Range , Q2996102 , Antarctica , Europe
# 5951 London Indian Film Festival , Q6670490 , London , Chicago
# 5958 Melnik Ridge , Q6813254 , Antarctica , Europe
# 5963 Tanga Region , Q389737 , Tanzania , Stockholm
# 21503 London Independent Film Festival , Q18160730 , London , Pasadena
# 21570 Brialmont Cove , Q86625 , Antarctica , Europe
# 21582 Atlantic Club Ridge , Q4816363 , Antarctica , Europe
# 21611 Hull Bay , Q281509 , Antarctica , Africa
# 21732 Bintulu Division , Q2607580 , Malaysia , Madagascar
# 21840 Edward VIII Bay , Q141648 , Antarctica , Europe
# 21857 Desolation Lava Field , Q5264867 , Canada , Singapore
# 21905 Penney Bay , Q281451 , Antarctica , Europe

# %%
def filtering(word, word_counts, min_count=2):
    if word == 'null':
        return 0, 'null'
    word_list = word.split(',')
    word_list = [word for word in word_list if word_counts.get(word, 0) >= min_count]
    word_list = sorted(word_list, key=lambda x: word_counts.get(x, 0), reverse=True)
    num = len(word_list)
    return num, ','.join(word_list)

def filtering2(dx, min_count, k):
    df = dx.copy()
    for i in range(len(df)):
        df.loc[i, 'sbj_hop_num'], df.loc[i, 'sbj_one_hop'] = filtering(df.loc[i, 'sbj_one_hop'], word_counts, min_count)
        df.loc[i, 'obj_true_hop_num'], df.loc[i, 'obj_one_hop'] = filtering(df.loc[i, 'obj_one_hop'], word_counts, min_count)
        df.loc[i, 'obj_new_hop_num'], df.loc[i, 'obj_new_one_hop'] = filtering(df.loc[i, 'obj_new_one_hop'], word_counts, min_count)

    well_list = []

    for i in range(len(df)):
        if (df.loc[i, 'sbj_hop_num']>=k and df.loc[i, 'obj_true_hop_num']>=k and df.loc[i, 'obj_new_hop_num']>=k):
            well_list.append(i)
    print(f'Total number of data with (freq >= {min_count}) and (length >= {k}) is {len(well_list)}({round(100 * len(well_list) / 21919, 2)}%)')

# %%
df = dx.copy()
for min_count in range(1, 11):
    for k in range(0, 11):
        filtering2(df, min_count, k)
# Out:
# Total number of data with (freq >= 1) and (length >= 0) is 21919(100.0%)
# Total number of data with (freq >= 1) and (length >= 1) is 21366(97.48%)
# Total number of data with (freq >= 1) and (length >= 2) is 19878(90.69%)
# Total number of data with (freq >= 1) and (length >= 3) is 18146(82.79%)
# Total number of data with (freq >= 1) and (length >= 4) is 16515(75.35%)
# Total number of data with (freq >= 1) and (length >= 5) is 15083(68.81%)
# Total number of data with (freq >= 1) and (length >= 6) is 13622(62.15%)
# Total number of data with (freq >= 1) and (length >= 7) is 12018(54.83%)
# Total number of data with (freq >= 1) and (length >= 8) is 10578(48.26%)
# Total number of data with (freq >= 1) and (length >= 9) is 9649(44.02%)
# Total number of data with (freq >= 1) and (length >= 10) is 8708(39.73%)
# Total number of data with (freq >= 2) and (length >= 0) is 21919(100.0%)
# Total number of data with (freq >= 2) and (length >= 1) is 20898(95.34%)
# Total number of data with (freq >= 2) and (length >= 2) is 18824(85.88%)
# Total number of data with (freq >= 2) and (length >= 3) is 16572(75.61%)
# Total number of data with (freq >= 2) and (length >= 4) is 14678(66.96%)
# Total number of data with (freq >= 2) and (length >= 5) is 13142(59.96%)
# Total number of data with (freq >= 2) and (length >= 6) is 11636(53.09%)
# Total number of data with (freq >= 2) and (length >= 7) is 10033(45.77%)
# Total number of data with (freq >= 2) and (length >= 8) is 8672(39.56%)
# Total number of data with (freq >= 2) and (length >= 9) is 7722(35.23%)
# Total number of data with (freq >= 2) and (length >= 10) is 6884(31.41%)
# Total number of data with (freq >= 3) and (length >= 0) is 21919(100.0%)
# Total number of data with (freq >= 3) and (length >= 1) is 20639(94.16%)
# Total number of data with (freq >= 3) and (length >= 2) is 18402(83.95%)
# Total number of data with (freq >= 3) and (length >= 3) is 15932(72.69%)
# Total number of data with (freq >= 3) and (length >= 4) is 14008(63.91%)
# Total number of data with (freq >= 3) and (length >= 5) is 12405(56.59%)
# Total number of data with (freq >= 3) and (length >= 6) is 10892(49.69%)
# Total number of data with (freq >= 3) and (length >= 7) is 9301(42.43%)
# Total number of data with (freq >= 3) and (length >= 8) is 7935(36.2%)
# Total number of data with (freq >= 3) and (length >= 9) is 7001(31.94%)
# Total number of data with (freq >= 3) and (length >= 10) is 6202(28.3%)
# Total number of data with (freq >= 4) and (length >= 0) is 21919(100.0%)
# Total number of data with (freq >= 4) and (length >= 1) is 20506(93.55%)
# Total number of data with (freq >= 4) and (length >= 2) is 18112(82.63%)
# Total number of data with (freq >= 4) and (length >= 3) is 15544(70.92%)
# Total number of data with (freq >= 4) and (length >= 4) is 13616(62.12%)
# Total number of data with (freq >= 4) and (length >= 5) is 11989(54.7%)
# Total number of data with (freq >= 4) and (length >= 6) is 10513(47.96%)
# Total number of data with (freq >= 4) and (length >= 7) is 8885(40.54%)
# Total number of data with (freq >= 4) and (length >= 8) is 7533(34.37%)
# Total number of data with (freq >= 4) and (length >= 9) is 6617(30.19%)
# Total number of data with (freq >= 4) and (length >= 10) is 5859(26.73%)
# Total number of data with (freq >= 5) and (length >= 0) is 21919(100.0%)
# Total number of data with (freq >= 5) and (length >= 1) is 20353(92.86%)
# Total number of data with (freq >= 5) and (length >= 2) is 17900(81.66%)
# Total number of data with (freq >= 5) and (length >= 3) is 15286(69.74%)
# Total number of data with (freq >= 5) and (length >= 4) is 13342(60.87%)
# Total number of data with (freq >= 5) and (length >= 5) is 11705(53.4%)
# Total number of data with (freq >= 5) and (length >= 6) is 10196(46.52%)
# Total number of data with (freq >= 5) and (length >= 7) is 8606(39.26%)
# Total number of data with (freq >= 5) and (length >= 8) is 7274(33.19%)
# Total number of data with (freq >= 5) and (length >= 9) is 6351(28.97%)
# Total number of data with (freq >= 5) and (length >= 10) is 5621(25.64%)
# Total number of data with (freq >= 6) and (length >= 0) is 21919(100.0%)
# Total number of data with (freq >= 6) and (length >= 1) is 20245(92.36%)
# Total number of data with (freq >= 6) and (length >= 2) is 17707(80.78%)
# Total number of data with (freq >= 6) and (length >= 3) is 15058(68.7%)
# Total number of data with (freq >= 6) and (length >= 4) is 13093(59.73%)
# Total number of data with (freq >= 6) and (length >= 5) is 11487(52.41%)
# Total number of data with (freq >= 6) and (length >= 6) is 9973(45.5%)
# Total number of data with (freq >= 6) and (length >= 7) is 8382(38.24%)
# Total number of data with (freq >= 6) and (length >= 8) is 7070(32.26%)
# Total number of data with (freq >= 6) and (length >= 9) is 6169(28.14%)
# Total number of data with (freq >= 6) and (length >= 10) is 5460(24.91%)
# Total number of data with (freq >= 7) and (length >= 0) is 21919(100.0%)
# Total number of data with (freq >= 7) and (length >= 1) is 20159(91.97%)
# Total number of data with (freq >= 7) and (length >= 2) is 17549(80.06%)
# Total number of data with (freq >= 7) and (length >= 3) is 14889(67.93%)
# Total number of data with (freq >= 7) and (length >= 4) is 12920(58.94%)
# Total number of data with (freq >= 7) and (length >= 5) is 11312(51.61%)
# Total number of data with (freq >= 7) and (length >= 6) is 9792(44.67%)
# Total number of data with (freq >= 7) and (length >= 7) is 8199(37.41%)
# Total number of data with (freq >= 7) and (length >= 8) is 6910(31.53%)
# Total number of data with (freq >= 7) and (length >= 9) is 6015(27.44%)
# Total number of data with (freq >= 7) and (length >= 10) is 5316(24.25%)
# Total number of data with (freq >= 8) and (length >= 0) is 21919(100.0%)
# Total number of data with (freq >= 8) and (length >= 1) is 20060(91.52%)
# Total number of data with (freq >= 8) and (length >= 2) is 17416(79.46%)
# Total number of data with (freq >= 8) and (length >= 3) is 14772(67.39%)
# Total number of data with (freq >= 8) and (length >= 4) is 12799(58.39%)
# Total number of data with (freq >= 8) and (length >= 5) is 11171(50.96%)
# Total number of data with (freq >= 8) and (length >= 6) is 9644(44.0%)
# Total number of data with (freq >= 8) and (length >= 7) is 8063(36.79%)
# Total number of data with (freq >= 8) and (length >= 8) is 6783(30.95%)
# Total number of data with (freq >= 8) and (length >= 9) is 5876(26.81%)
# Total number of data with (freq >= 8) and (length >= 10) is 5181(23.64%)
# Total number of data with (freq >= 9) and (length >= 0) is 21919(100.0%)
# Total number of data with (freq >= 9) and (length >= 1) is 19970(91.11%)
# Total number of data with (freq >= 9) and (length >= 2) is 17287(78.87%)
# Total number of data with (freq >= 9) and (length >= 3) is 14645(66.81%)
# Total number of data with (freq >= 9) and (length >= 4) is 12666(57.79%)
# Total number of data with (freq >= 9) and (length >= 5) is 11030(50.32%)
# Total number of data with (freq >= 9) and (length >= 6) is 9516(43.41%)
# Total number of data with (freq >= 9) and (length >= 7) is 7921(36.14%)
# Total number of data with (freq >= 9) and (length >= 8) is 6654(30.36%)
# Total number of data with (freq >= 9) and (length >= 9) is 5747(26.22%)
# Total number of data with (freq >= 9) and (length >= 10) is 5060(23.08%)
# Total number of data with (freq >= 10) and (length >= 0) is 21919(100.0%)
# Total number of data with (freq >= 10) and (length >= 1) is 19909(90.83%)
# Total number of data with (freq >= 10) and (length >= 2) is 17203(78.48%)
# Total number of data with (freq >= 10) and (length >= 3) is 14540(66.34%)
# Total number of data with (freq >= 10) and (length >= 4) is 12560(57.3%)
# Total number of data with (freq >= 10) and (length >= 5) is 10932(49.87%)
# Total number of data with (freq >= 10) and (length >= 6) is 9403(42.9%)
# Total number of data with (freq >= 10) and (length >= 7) is 7822(35.69%)
# Total number of data with (freq >= 10) and (length >= 8) is 6556(29.91%)
# Total number of data with (freq >= 10) and (length >= 9) is 5665(25.85%)
# Total number of data with (freq >= 10) and (length >= 10) is 4973(22.69%)

# %%
sample_list = random.sample(well_list, 1000)
sample_list.sort()
df = df.iloc[sample_list]

# %%
df = df.reset_index(drop = True)
df
# Out:
#      index                subject subject_id  \
# 0        4                   Lyon       Q456
# 1       90                  Rabat      Q3551
# 2      143  Delusions of Grandeur    Q705247
# 3      145           Falling Down    Q289598
# 4      168         Cees Nooteboom    Q158394
# ..     ...                    ...        ...
# 995  21872              Paul Huet   Q1354027
# 996  21893         Wilkie Collins    Q210740
# 997  21907    Mary Wollstonecraft    Q101638
# 998  21909               Tel Aviv     Q33935
# 999  21917      Umayyad Caliphate   Q8575586
#
#                                            sbj_one_hop  sbj_hop_num  obj_true  \
# 0    Europe,France,Kyiv,NADD Wikidata project,Saint...           37    Beirut
# 1    Granat Encyclopedic Dictionary,Armenian Soviet...           20  Damascus
# 2    Germany,Spain,Madrid,Barcelona,film,color,vide...           21    French
# 3    Los Angeles,film,color,video on demand,drama f...           33    France
# 4    human,male,writer,works protected by copyright...           32     Dutch
# ..                                                 ...          ...       ...
# 995  human,male,National Gallery of Victoria,copyri...           33     Paris
# 996  human,male,writer,United Kingdom of Great Brit...           22    London
# 997  human,New International Encyclopedia,German,Lo...           42    French
# 998  English,Israel,Mexico City,Organization of Wor...           42     Milan
# 999  New International Encyclopedia,Asia,Islam,Afri...           24  Damascus
#
#     obj_true_id                                        obj_one_hop  \
# 0         Q3820  Catholic Encyclopedia,Lebanon,largest city,Cre...
# 1         Q3766  Catholic Encyclopedia,Bible Encyclopedia of Ar...
# 2          Q150  Belgium,Switzerland,Algeria,Vietnam,Morocco,La...
# 3          Q142  Jewish Encyclopedia of Brockhaus and Efron,Eur...
# 4         Q7411  New International Encyclopedia,Small Brockhaus...
# ..          ...                                                ...
# 995         Q90  Catholic Encyclopedia,Europe,Genadendal Music ...
# 996         Q84  Granat Encyclopedic Dictionary,Catholic Encycl...
# 997        Q150  Italy,Belgium,Switzerland,Algeria,Vietnam,Moro...
# 998        Q490  Granat Encyclopedic Dictionary,Jewish Encyclop...
# 999       Q3766  Catholic Encyclopedia,city,national capital,To...
#
#      obj_true_hop_num      obj_new obj_new_id  \
# 0                  39       Manila      Q1461
# 1                  37     Istanbul       Q406
# 2                  71      English      Q1860
# 3                 185  Philippines       Q928
# 4                  53   Indonesian      Q9240
# ..                ...          ...        ...
# 995                60       Venice       Q641
# 996               104      Chicago      Q1297
# 997                73      English      Q1860
# 998                65        Tokyo      Q1490
# 999                39       Athens      Q1524
#
#                                        obj_new_one_hop  obj_new_hop_num  \
# 0    New International Encyclopedia,Philippines,Asi...               82
# 1    Europe,Sytin Military Encyclopedia,Asia,Creati...               70
# 2    Granat Encyclopedic Dictionary,Armenian Soviet...              149
# 3    New International Encyclopedia,Laos,Sri Lanka,...              275
# 4    English,Indonesia,Arabic,agglutinative languag...               28
# ..                                                 ...              ...
# 995  Granat Encyclopedic Dictionary,Italy,big city,...               78
# 996  United States of America,New International Enc...               25
# 997  Granat Encyclopedic Dictionary,Armenian Soviet...              147
# 998  Asia,largest city,Japan,Berlin,megacity,global...               89
# 999  Sytin Military Encyclopedia,metropolis,Kyiv,Be...              104
#
#         view
# 0    2376138
# 1    1201331
# 2      28776
# 3    2256340
# 4      43963
# ..       ...
# 995    10248
# 996   397478
# 997  1873516
# 998  4019548
# 999  4127429
#
# [1000 rows x 14 columns]
