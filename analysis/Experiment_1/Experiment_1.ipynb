# %%
from tqdm import tqdm
import torch.nn.functional as F
import pandas as pd
import random
import json
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from setting import set_seed
set_seed(42)

# %%
# k : output data_size
k=5

# %%
df_base = pd.read_excel("../../data/one_hop/BERT_FREQ1_preprocessed_df2.xlsx")
df_base = df_base.dropna()
df_base = df_base.reset_index(drop = True)
new_columns = ['sbj_hop_test', 'obj_true_hop_test', 'obj_new_hop_test']
for col in new_columns:
    df_base[col] = ''

# %%
with open('../../counterfact_memit.jsonl', 'r', encoding='utf-8') as file:
    data = [json.loads(line) for line in file]

# %%
def extract(df, data):
    result = []
    for idx in range(len(df)):
        dt = data[df.loc[idx, 'index']]
        
        result.append({
            "case_id": str(df.loc[idx, "index"]),
            "prompt": dt['requested_rewrite']['prompt'],
            "subject" : df.loc[idx, 'subject'],
            "fact_knowledge" : df.loc[idx, 'obj_true'],
            "edited_knowledge" : df.loc[idx, 'obj_new'],
            "relation_id": dt['requested_rewrite']['relation_id'],
            "rephrased_prompt" : dt['paraphrase_prompts'][0],
            "locality_prompt" : dt['neighborhood_prompts'][0],
            "locality_ground_truth" : df.loc[idx, 'obj_true'],
            
            
            "sbj_hop_test" : df.loc[idx, 'sbj_hop_test'].split(','),
            "obj_true_hop_test" : df.loc[idx, 'obj_true_hop_test'].split(','),
            "obj_new_hop_test" : df.loc[idx, 'obj_new_hop_test'].split(','),
        })
    return result

# %% [markdown]
# # 1. Random 5개

# %%
df = df_base.copy()

# %%
def filter_a(word_list, k=10):
    word_lists = word_list.split(',')
    if (len(word_lists) < k):
        return word_list
    selected_list = random.sample(word_lists, k)
    return ','.join(selected_list)

for i in range(len(df)):
    df.loc[i, 'sbj_hop_test'] = filter_a(df.loc[i, 'sbj_one_hop'], k)
    df.loc[i, 'obj_true_hop_test'] = filter_a(df.loc[i, 'obj_one_hop'], k)
    df.loc[i, 'obj_new_hop_test'] = filter_a(df.loc[i, 'obj_new_one_hop'], k)

# %%
df_a = extract(df, data)   

with open("df_exp1_a_1000.json", "w") as json_file:
    json.dump(extract(df.iloc[:1000], data), json_file, indent=4, ensure_ascii=False)
    
with open("df_exp1_a_full.json", "w") as json_file:
    json.dump(df_a, json_file, indent=4, ensure_ascii=False)

# %% [markdown]
# # 2. BERT 유사도 상위 5개

# %%
df = df_base.copy()

# %%
def filter_b(word_list, k=10):
    word_lists = word_list.split(',')
    if (len(word_lists) < k):
        return word_list
    return ','.join(word_lists[:k])

for i in tqdm(range(len(df))):
    df.loc[i, 'sbj_hop_test'] = filter_b(df.loc[i, 'sbj_hop'], k)   
    df.loc[i, 'obj_true_hop_test'] = filter_b(df.loc[i, 'obj_true_hop'], k)
    df.loc[i, 'obj_new_hop_test'] = filter_b(df.loc[i, 'obj_new_hop'], k)
# Out:
# 100%|██████████| 21782/21782 [00:04<00:00, 5039.99it/s]

# %%
df_b = extract(df, data)     

with open("df_exp1_b_1000.json", "w") as json_file:
    json.dump(extract(df.iloc[:1000], data), json_file, indent=4, ensure_ascii=False)

with open("df_exp1_b_full.json", "w") as json_file:
    json.dump(df_b, json_file, indent=4, ensure_ascii=False)

# %% [markdown]
# # 3. 빈도수 하위 5개 단어

# %%
df = df_base.copy()

# %%
def filter_c(word_list, k = 10):
    word_lists = word_list.split(',')
    # 저장할 때 내림차순 정렬 해놨음
    reversed_list = word_lists[::-1]
    word_lists = reversed_list[:k]
    return ','.join(word_lists)

for i in range(len(df)):
    df.loc[i, 'sbj_hop_test'] = filter_c(df.loc[i, 'sbj_one_hop'], k)
    df.loc[i, 'obj_true_hop_test'] = filter_c(df.loc[i, 'obj_one_hop'], k)
    df.loc[i, 'obj_new_hop_test'] = filter_c(df.loc[i, 'obj_new_one_hop'], k)

# %%
df_c = extract(df, data)     

with open("df_exp1_c_1000.json", "w") as json_file:
    json.dump(extract(df.iloc[:1000], data), json_file, indent=4, ensure_ascii=False)
    
with open("df_exp1_c_full.json", "w") as json_file:
    json.dump(df_c, json_file, indent=4, ensure_ascii=False)

# %% [markdown]
# # 4. 유사도 10개 -> 빈도수 5개 단어

# %%
df = df_base.copy()

# %%
def filter_d(word_freq, word_bert, k = 10):
    reversed_list = word_freq.split(',')[::-1]
    bert_list = word_bert.split(',')[:2*k]
    
    ans_sorted = sorted(bert_list, key=lambda x: reversed_list.index(x))
    ans_sorted = ans_sorted[:k]
    return ','.join(ans_sorted)

for i in tqdm(range(len(df))):
    df.loc[i, 'sbj_hop_test'] = filter_d(df.loc[i, 'sbj_one_hop'], df.loc[i, 'sbj_hop'], k)   
    df.loc[i, 'obj_true_hop_test'] = filter_d(df.loc[i, 'obj_one_hop'], df.loc[i, 'obj_true_hop'], k)
    df.loc[i, 'obj_new_hop_test'] = filter_d(df.loc[i, 'obj_new_one_hop'], df.loc[i, 'obj_new_hop'], k)
# Out:
# 100%|██████████| 21782/21782 [00:05<00:00, 3950.55it/s]

# %%
df_d = extract(df, data)     
with open("df_exp1_d_1000.json", "w") as json_file:
    json.dump(extract(df.iloc[:1000], data), json_file, indent=4, ensure_ascii=False)
with open("df_exp1_d_full.json", "w") as json_file:
    json.dump(df_d, json_file, indent=4, ensure_ascii=False)

# %% [markdown]
# # 5. 빈도수 10개 -> 유사도 5개 단어

# %%
df = df_base.copy()

# %%
def filter_e(word_freq, word_bert, k = 10):
    reversed_list = word_freq.split(',')[::-1][:2*k]
    bert_list = word_bert.split(',')
    
    ans_sorted = sorted(reversed_list, key=lambda x: bert_list.index(x))
    ans_sorted = ans_sorted[:k]
    return ','.join(ans_sorted)

for i in tqdm(range(len(df))):
    df.loc[i, 'sbj_hop_test'] = filter_e(df.loc[i, 'sbj_one_hop'], df.loc[i, 'sbj_hop'], k)   
    df.loc[i, 'obj_true_hop_test'] = filter_e(df.loc[i, 'obj_one_hop'], df.loc[i, 'obj_true_hop'], k)
    df.loc[i, 'obj_new_hop_test'] = filter_e(df.loc[i, 'obj_new_one_hop'], df.loc[i, 'obj_new_hop'], k)
# Out:
# 100%|██████████| 21782/21782 [00:06<00:00, 3366.10it/s]

# %%
df_e = extract(df, data)     
with open("df_exp1_e_1000.json", "w") as json_file:
    json.dump(extract(df.iloc[:1000], data), json_file, indent=4, ensure_ascii=False)
with open("df_exp1_e_full.json", "w") as json_file:
    json.dump(df_e, json_file, indent=4, ensure_ascii=False)

# %%
df_base
# Out:
#        index                          subject subject_id  \
# 0          0                Danielle Darrieux    Q234149
# 1          1             Edwin of Northumbria    Q348955
# 2          2                      Toko Yasuda   Q7813654
# 3          3  Autonomous University of Madrid    Q788091
# 4          4                             Lyon       Q456
# ...      ...                              ...        ...
# 21777  21914                  Georges Bernier   Q3406819
# 21778  21915              Jean-Pierre Dionnet    Q968155
# 21779  21916                   Bong Jung-keun     Q50609
# 21780  21917                Umayyad Caliphate   Q8575586
# 21781  21918                           Subair   Q7630724
#
#                                              sbj_one_hop  sbj_hop_num  \
# 0      human,France,female,actor,voice,film actor,fil...           21
# 1      Brockhaus and Efron Encyclopedic Dictionary,En...           12
# 2      human,Japan,female,musician,keyboard instrumen...           13
# 3      Spanish,Medvik,Agence universitaire de la Fran...            9
# 4      Brockhaus and Efron Encyclopedic Dictionary,Sm...           47
# ...                                                  ...          ...
# 21777  human,France,male,writer,Paris,natural causes,...           22
# 21778  human,France,male,Paris,journalist,television ...            7
# 21779  human,male,South Korea,Seoul,Korean,baseball,b...           11
# 21780  Europe,Armenian Soviet Encyclopedia,New Intern...           27
# 21781  human,male,India,Malayalam,Kochi,Panoor Munici...            6
#
#            obj_true obj_true_id  \
# 0            French        Q150
# 1      Christianity       Q5043
# 2            guitar       Q6607
# 3             Spain         Q29
# 4            Beirut       Q3820
# ...             ...         ...
# 21777        French        Q150
# 21778        French        Q150
# 21779       pitcher    Q1048902
# 21780      Damascus       Q3766
# 21781         actor      Q33999
#
#                                              obj_one_hop  obj_true_hop_num  \
# 0      Brockhaus and Efron Encyclopedic Dictionary,Sm...                99
# 1      Brockhaus and Efron Encyclopedic Dictionary,Sm...                25
# 2      Brockhaus and Efron Encyclopedic Dictionary,Sm...                32
# 3      Brockhaus and Efron Encyclopedic Dictionary,Sm...               231
# 4      Brockhaus and Efron Encyclopedic Dictionary,Sm...                51
# ...                                                  ...               ...
# 21777  Brockhaus and Efron Encyclopedic Dictionary,Sm...                99
# 21778  Brockhaus and Efron Encyclopedic Dictionary,Sm...                99
# 21779  baseball,baseball player,baseball position,sof...                 7
# 21780  Brockhaus and Efron Encyclopedic Dictionary,Sm...                54
# 21781  Brockhaus and Efron Encyclopedic Dictionary,Sm...                63
#
#           obj_new obj_new_id  \
# 0         English      Q1860
# 1           Islam       Q432
# 2           piano      Q5994
# 3          Sweden        Q34
# 4          Manila      Q1461
# ...           ...        ...
# 21777     Russian      Q7737
# 21778     Spanish      Q1321
# 21779  outfielder   Q1142885
# 21780      Athens      Q1524
# 21781    composer     Q36834
#
#                                          obj_new_one_hop  obj_new_hop_num  \
# 0      Brockhaus and Efron Encyclopedic Dictionary,Sm...              175
# 1      Brockhaus and Efron Encyclopedic Dictionary,Sm...               76
# 2      Brockhaus and Efron Encyclopedic Dictionary,Sm...               11
# 3      Brockhaus and Efron Encyclopedic Dictionary,Sm...              212
# 4      Brockhaus and Efron Encyclopedic Dictionary,Sm...               93
# ...                                                  ...              ...
# 21777  Brockhaus and Efron Encyclopedic Dictionary,Sm...               67
# 21778  Brockhaus and Efron Encyclopedic Dictionary,Sm...               67
# 21779  baseball,baseball position,left fielder,right ...                5
# 21780  Brockhaus and Efron Encyclopedic Dictionary,Sm...              120
# 21781  occupation,composed musical work,musician,imag...               45
#
#           view                                            sbj_hop  \
# 0       222931  Georges Mitsinkides,voice,Bordeaux,film,fallin...
# 1       177019  Whitby Abbey,Catholic saint,Hatfield Chase,Cwe...
# 2        74330  Japan,musician,human,Enon,rock music,female,To...
# 3        87615  Coalition for Advancing Research Assessment,Eu...
# 4      2376138  France,Milan,Francheville,Guangzhou,college to...
# ...        ...                                                ...
# 21777    13177  Odile Vaudelle,Paris,Grodada,Charlie Mensuel,F...
# 21778    11530  France,journalist,comics writer,Paris,televisi...
# 21779    12063  Sungkyunkwan University,South Korea,Seoul,Kore...
# 21780  4127429  Byzantine Empire,Medieval Greek,Kingdom of Tol...
# 21781    41064  Kochi,India,Malayalam,human,Panoor Municipalit...
#
#                                             obj_true_hop  \
# 0      Chad,Lebanon,Canada,Luxembourg,franska,Jura,Mo...
# 1      Christendom,hiristiyanlik,hristiyanlik,Christ,...
# 2      chitarra,gitarre,Gitarre,machine head,tgu,Gita...
# 3      Community of Madrid,Madrid,Region of Murcia,es...
# 4      Marseille,Damascus,Istanbul,Montreal,Quebec Ci...
# ...                                                  ...
# 21777  Jura,Luxembourg,Lebanon,France,Monaco,Switzerl...
# 21778  Hainaut,Andorra,Walloon Brabant,Niger,Flemish ...
# 21779  metalka,bowler,lanceuse,softball,baseball,base...
# 21780  Syria,populated place in Syria,damascenus,Emir...
# 21781  atriz,aktour,attore,zat,aktres,actriz,aktoro,a...
#
#                                              obj_new_hop sbj_hop_test  \
# 0      natural language,language,Greek,modern languag...
# 1      Muslim,Judaism,Muhammad,major religion,humanit...
# 2      pianist,keyboard instrument,Klavier,A,kpf,klav...
# 3      Denmark,Finland,Canada,Japan,Russia,Malaysia,A...
# 4      Jakarta,Beijing,Osaka,metropolis,Santiago,Sacr...
# ...                                                  ...          ...
# 21777  Russia,language,natural language,rus,East Slav...
# 21778  Spain,human language,Peru,natural language,Gib...
# 21779  baseball position,baseball,left fielder,right ...
# 21780  Tbilisi,Bucharest,Istanbul,Havana,Moscow,Sofia...
# 21781  musician,author,official website,image,komponi...
#
#       obj_true_hop_test obj_new_hop_test
# 0
# 1
# 2
# 3
# 4
# ...                 ...              ...
# 21777
# 21778
# 21779
# 21780
# 21781
#
# [21782 rows x 20 columns]

# %% [markdown]
# # 6. Log prob 상위 5개

# %%
import pandas as pd
df = pd.read_excel("../../data/one_hop/log_prob_preprocessed_df2.xlsx")
new_columns = ['sbj_hop_test', 'obj_true_hop_test', 'obj_new_hop_test']
for col in new_columns:
    df[col] = ''

# %%
def filter_f(words, k = 10):
    return ','.join(words.split(',')[:k])

for i in tqdm(range(len(df))):
    df.loc[i, 'sbj_hop_test'] = filter_f(df.loc[i, 'sbj_one_hop'], k)   
    df.loc[i, 'obj_true_hop_test'] = filter_f(df.loc[i, 'obj_one_hop'], k)
    df.loc[i, 'obj_new_hop_test'] = filter_f(df.loc[i, 'obj_new_one_hop'], k)
# Out:
# 100%|██████████| 21782/21782 [00:05<00:00, 3724.15it/s]

# %%
df.head()
# Out:
#    index                          subject subject_id  \
# 0      0                Danielle Darrieux    Q234149
# 1      1             Edwin of Northumbria    Q348955
# 2      2                      Toko Yasuda   Q7813654
# 3      3  Autonomous University of Madrid    Q788091
# 4      4                             Lyon       Q456
#
#                                          sbj_one_hop  sbj_hop_num  \
# 0  singer,female,Bordeaux,actor,theatre,voice,hum...           21
# 1  saint,male,sovereign,human,English,Catholic sa...           12
# 2  Japan,musician,female,human,rock music,keyboar...           13
# 3  Spanish,Biology Department,UAM,Medvik,MAUAM,YE...            9
# 4  Birmingham,Frankfurt,Leipzig,Milan,France,Euro...           47
#
#        obj_true obj_true_id  \
# 0        French        Q150
# 1  Christianity       Q5043
# 2        guitar       Q6607
# 3         Spain         Q29
# 4        Beirut       Q3820
#
#                                          obj_one_hop  obj_true_hop_num  \
# 0  conditional,Guinea,Jersey,imperative,Luxembour...                99
# 1  Bible,Judaism,Jesus,Christian,Jerusalem,Christ...                25
# 2  neck,nut,long,bridge,body,fret,sound hole,mapl...                32
# 3  Portugal,Portuguese,Peru,Serbia,country,Malta,...               231
# 4  Dubai,Lebanon,Cairo,Istanbul,Marseille,Damascu...                51
#
#    obj_new obj_new_id                                    obj_new_one_hop  \
# 0  English      Q1860  feminine,Jersey,Gibraltar,masculine,Malaysia,e...
# 1    Islam       Q432  salah,Judaism,allegiance,Arabic,Muhammad,surre...
# 2    piano      Q5994  A,keyboard instrument,kpf,pianist,klaver,Klavi...
# 3   Sweden        Q34  Guinea,svenska,Belarus,Iran,Swedish,Hungary,Ar...
# 4   Manila      Q1461  Asia,Guam,Philippines,Taipei,Winnipeg,Santiago...
#
#    obj_new_hop_num     view                                 sbj_hop_test  \
# 0              175   222931         singer,female,Bordeaux,actor,theatre
# 1               76   177019           saint,male,sovereign,human,English
# 2               11    74330       Japan,musician,female,human,rock music
# 3              212    87615  Spanish,Biology Department,UAM,Medvik,MAUAM
# 4               93  2376138    Birmingham,Frankfurt,Leipzig,Milan,France
#
#                                  obj_true_hop_test  \
# 0  conditional,Guinea,Jersey,imperative,Luxembourg
# 1          Bible,Judaism,Jesus,Christian,Jerusalem
# 2                        neck,nut,long,bridge,body
# 3          Portugal,Portuguese,Peru,Serbia,country
# 4           Dubai,Lebanon,Cairo,Istanbul,Marseille
#
#                                obj_new_hop_test
# 0  feminine,Jersey,Gibraltar,masculine,Malaysia
# 1      salah,Judaism,allegiance,Arabic,Muhammad
# 2      A,keyboard instrument,kpf,pianist,klaver
# 3           Guinea,svenska,Belarus,Iran,Swedish
# 4         Asia,Guam,Philippines,Taipei,Winnipeg

# %%
df_f = extract(df, data)     
with open("df_exp1_f_1000.json", "w") as json_file:
    json.dump(extract(df.iloc[:1000], data), json_file, indent=4, ensure_ascii=False)
with open("df_exp1_f_full.json", "w") as json_file:
    json.dump(df_f, json_file, indent=4, ensure_ascii=False)

# %%
with open("df_exp1_f_5000.json", "w") as json_file:
    json.dump(extract(df.iloc[:5000], data), json_file, indent=4, ensure_ascii=False)
