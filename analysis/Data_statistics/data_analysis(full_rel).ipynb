# %%
# %cd
# Out:
# /home/gyubin
# /home/gyubin/anaconda3/envs/EasyEdit/lib/python3.9/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /home/gyubin/anaconda3/envs/EasyEdit/lib/python3.9/site-packages/IPython/core/magics/osm.py:428: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# # 1. Plotting

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_sbj = pd.read_excel('./Knowledge_Editing_Dataset/data/one_hop/df_sbj_full_rel++.xlsx')

# NaN 값을 빈 문자열로 대체하고 모든 값을 문자열로 변환
df_sbj['one_hop'] = df_sbj['one_hop'].fillna('').astype(str)

# 각 one_hop에 대해 단어 개수를 계산
df_sbj['word_count'] = df_sbj['one_hop'].apply(lambda x: 0 if x == '' else len(x.split(',')))

# 히스토그램 생성
plt.figure(figsize=(10, 6))
counts, bins, patches = plt.hist(df_sbj['word_count'], bins=range(0, df_sbj['word_count'].max() + 2), alpha=0.7, edgecolor='black')

# 각 막대 위에 빈도수 레이블 추가
for count, x in zip(counts, bins[:-1]):
    if count > 0:
        plt.text(x + 0.4, count, str(int(count)), ha='center', va='bottom', fontsize=8)

# 그래프 레이블 설정
plt.title('Subject count')
plt.xlabel('Value')
plt.ylabel('Frequency')

# 그래프 출력
plt.show()

# 특정 기준 값들에 대해 개수와 비율을 계산하는 함수 정의
def count_and_ratio(df, column, thresholds):
    total_count = len(df)
    results = []
    for threshold in thresholds:
        count = df[column][df[column] < threshold].count()
        ratio = (count / total_count) * 100
        results.append(f"Count smaller than {threshold}: {count}({ratio:.2f}%)")
    return results

# 기준 값 리스트
thresholds = [1, 3, 5, 10]

# 결과 출력
results = count_and_ratio(df_sbj, 'word_count', thresholds)
for result in results:
    print(result)
# Out:
# Count smaller than 1: 2(0.01%)
# Count smaller than 3: 60(0.27%)
# Count smaller than 5: 157(0.72%)
# Count smaller than 10: 1476(6.73%)

# %%
print(df_sbj.loc[0, 'subject'])
for i in df_sbj.loc[0, 'one_hop'].split(','):
    print(i)
# Out:
# Danielle Darrieux
# Darrieux
# Obálky knih
# ola2002159092
# Q18040452
# 406072
# Danielle Darrieux
# XX4580778
# 097152196
# 99003663
# n2009093931
# 37342
# celebrity/danielle_darrieux
# 768/000092492
# 123
# 50018147
# 00000003388
# 0021527
# 872662
# Danielle Yvonne Marie Antoinette Darrieux
# 302153
# 00064968
# a0000003601717
# person/danielle-darrieux
# 91856
# I00371355
# 000587083
# 370289
# 46983
# p17063
# 1931-01-01T00:00:00Z
# 2010-01-01T00:00:00Z
# 1.64
# 223112
# 82883
# Danielle-darrieux
# 240317
# 10599
# 17880
# 6000000021702418818
# 19583
# 13363
# 25390
# people/danielle-darrieux
# 8a51faf8a34445d081a15de657f44bc3
# Darrieux-1
# 44418
# 02-A003155459
# 2048
# n0001186
# 3258979
# 42624
# danielle-darrieux
# 13622
# 18928
# 1397375
# w66409d5
# 146075
# 87097990506579
# 1569352
# 19055
# 7260
# 170800
# 4865
# Danielle_Darrieux
# 4ce2b9ef3474d
# 61304
# 35960401
# 5610
# 14567
# 29340
# 2085
# 946
# 236016
# Danielle-Darrieux
# darrieux-danielle
# 63051
# KAC2020L2623
# 2361
# 1048285
# 35562
# 20233
# 64jmwrwq39zdjgj
# danielle-darrieux-20063
# M00000062962
# personnage/wd/115710
# 17264
# 375066
# 119082
# 7013
# 37059
# danielle-darrieux-lyrics.html
# 37971
# 46717
# French
# voice
# European Film Award for Best Actress
# Olivier Darrieux
# Category:Danielle Darrieux
# Danielle Darrieux filmography
# Molière Award for Best Actress
# César Award
# Porfirio Rubirosa
# http://commons.wikimedia.org/wiki/Special:FilePath/Danielle%20Darrieux%20Five%20Fingers%202.jpg
# 0000000121040114
# 117444333
# 120051397
# n86138439
# 12530970k
# 034566562
# DA13239992
# nm0201638
# 35225748
# b01319ec-5fbf-48ad-b208-6a338f7338be
# http://commons.wikimedia.org/wiki/Special:FilePath/LL-Q150%20%28fra%29-Exilexi-Danielle%20Darrieux.wav
# 184411411
# 1917-05-01T00:00:00Z
# 2017-10-17T00:00:00Z
# /m/04r89g
# 9810655595705606
# 2592
# 3890729
# 000217258
# LNB:BCTF;=xs
# agent/base/152353
# 12648
# 5944
# p=danielle;n=darrieux
# 13945
# darrieuxd
# 152925
# ncf12117080
# 987007427008705171
# 1072
# 2507
# 40710
# a/044efe0a-fca9-4cef-81c3-f3d4271930c3
# Tzggy-helT9N
# 256191160
# 173630
# 1144
# daniel_dare
# 181444
# 01410/eu_d_0225/d0225
# daniel-dare
# E39PBJB4hWrPYkGHbVx3wxWhpP
# danielle-darrieux-en9iv7h9
# 29236
# 1140563741747467648
# 7_p-yNOBb
# danielle-darrieux-5213
# 37303
# 160418212
# 27254046
# singer
# actor
# Bois-le-Roi
# film
# Henri Decoin
# film actor
# France
# human
# theatre
# stage actor
# Bordeaux
# Marie-Louise Darrieux
# female
# Officer of Arts and Letters
# falling from height
# Georges Mitsinkides
# SAPA Foundation
#  Swiss Archive of the Performing Arts
# Cemetery of Marnes-la-Coquette
# Commander of the Legion of Honour
# Honorary César
# Silver Bear for Outstanding Artistic Contribution

# %%
df_obj_true = pd.read_excel('./Knowledge_Editing_Dataset/data/one_hop/df_obj_true_full_rel++.xlsx')

# NaN 값을 빈 문자열로 대체하고 모든 값을 문자열로 변환
df_obj_true['obj_one_hop'] = df_obj_true['obj_one_hop'].fillna('').astype(str)

# 각 one_hop에 대해 단어 개수를 계산
df_obj_true['word_count'] = df_obj_true['obj_one_hop'].apply(lambda x: 0 if x == '' else len(x.split(',')))

# 히스토그램 생성
plt.figure(figsize=(10, 6))
counts, bins, patches = plt.hist(df_obj_true['word_count'], bins=range(0, df_obj_true['word_count'].max() + 2), alpha=0.7, edgecolor='black')

# 각 막대 위에 빈도수 레이블 추가
for count, x in zip(counts, bins[:-1]):
    if count > 0:
        plt.text(x + 0.4, count, str(int(count)), ha='center', va='bottom', fontsize=8)

# 그래프 레이블 설정
plt.title('Object True count')
plt.xlabel('Value')
plt.ylabel('Frequency')

# 그래프 출력
plt.show()

# 특정 기준 값들에 대해 개수와 비율을 계산하는 함수 정의
def count_and_ratio(df, column, thresholds):
    total_count = len(df)
    results = []
    for threshold in thresholds:
        count = df[column][df[column] < threshold].count()
        ratio = (count / total_count) * 100
        results.append(f"Count smaller than {threshold}: {count}({ratio:.2f}%)")
    return results

# 기준 값 리스트
thresholds = [1, 3, 5, 10]

# 결과 출력
results = count_and_ratio(df_obj_true, 'word_count', thresholds)
for result in results:
    print(result)
# Out:
# Count smaller than 1: 0(0.00%)
# Count smaller than 3: 0(0.00%)
# Count smaller than 5: 0(0.00%)
# Count smaller than 10: 8(0.04%)

# %%
df_obj_new = pd.read_excel('./Knowledge_Editing_Dataset/data/one_hop/df_obj_new_full_rel++.xlsx')

# NaN 값을 빈 문자열로 대체하고 모든 값을 문자열로 변환
df_obj_new['obj_new_one_hop'] = df_obj_new['obj_new_one_hop'].fillna('').astype(str)

# 각 one_hop에 대해 단어 개수를 계산
df_obj_new['word_count'] = df_obj_new['obj_new_one_hop'].apply(lambda x: 0 if x == '' else len(x.split(',')))

# 히스토그램 생성
plt.figure(figsize=(10, 6))
counts, bins, patches = plt.hist(df_obj_new['word_count'], bins=range(0, df_obj_new['word_count'].max() + 2), alpha=0.7, edgecolor='black')

# 각 막대 위에 빈도수 레이블 추가
for count, x in zip(counts, bins[:-1]):
    if count > 0:
        plt.text(x + 0.4, count, str(int(count)), ha='center', va='bottom', fontsize=8)

# 그래프 레이블 설정
plt.title('Object New count')
plt.xlabel('Value')
plt.ylabel('Frequency')

# 그래프 출력
plt.show()

# 특정 기준 값들에 대해 개수와 비율을 계산하는 함수 정의
def count_and_ratio(df, column, thresholds):
    total_count = len(df)
    results = []
    for threshold in thresholds:
        count = df[column][df[column] < threshold].count()
        ratio = (count / total_count) * 100
        results.append(f"Count smaller than {threshold}: {count}({ratio:.2f}%)")
    return results

# 기준 값 리스트
thresholds = [1, 3, 5, 10]

# 결과 출력
results = count_and_ratio(df_obj_new, 'word_count', thresholds)
for result in results:
    print(result)
# Out:
# Count smaller than 1: 0(0.00%)
# Count smaller than 3: 0(0.00%)
# Count smaller than 5: 0(0.00%)
# Count smaller than 10: 10(0.05%)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# NaN 값을 빈 문자열로 대체하고 모든 값을 문자열로 변환
df_sbj['one_hop'] = df_sbj['one_hop'].fillna('').astype(str)
df_obj_true['obj_one_hop'] = df_obj_true['obj_one_hop'].fillna('').astype(str)
df_obj_new['obj_new_one_hop'] = df_obj_new['obj_new_one_hop'].fillna('').astype(str)

# 각 one_hop에 대해 단어 개수를 계산x
df_sbj['word_count'] = df_sbj['one_hop'].apply(lambda x: 0 if x == '' else len(x.split(',')))
df_obj_true['word_count'] = df_obj_true['obj_one_hop'].apply(lambda x: 0 if x == '' else len(x.split(',')))
df_obj_new['word_count'] = df_obj_new['obj_new_one_hop'].apply(lambda x: 0 if x == '' else len(x.split(',')))

# 단어 개수를 하나의 배열로 결합
combined_counts = df_sbj['word_count'] + df_obj_true['word_count'] + df_obj_new['word_count']

# 히스토그램 생성
plt.figure(figsize=(10, 6))
plt.hist(combined_counts, bins=range(0, combined_counts.max() + 2), alpha=0.5, edgecolor='black')

# 각 막대 위에 빈도수 레이블 추가
counts, bins = np.histogram(combined_counts, bins=range(0, combined_counts.max() + 2))
for count, x in zip(counts, bins[:-1]):
    if count > 0:
        plt.text(x + 0.4, count, str(int(count)), ha='center', va='bottom', fontsize=8)

# 그래프에 레이블 추가
plt.title('Total Count')
plt.xlabel('Value')
plt.ylabel('Frequency')

# 그래프 출력
plt.show()

# 특정 기준 값들에 대해 개수와 비율을 계산하는 함수 정의
def count_and_ratio(series, thresholds):
    total_count = len(series)
    results = []
    for threshold in thresholds:
        count = (series < threshold).sum()  # < threshold에 해당하는 개수 계산
        ratio = (count / total_count) * 100
        results.append(f"Count smaller than {threshold}: {count} ({ratio:.2f}%)")
    return results

# 기준 값 리스트
thresholds = [1, 3, 5, 10]

# 결과 출력
results = count_and_ratio(combined_counts, thresholds)

# 결과 출력
for result in results:
    print(result)
# Out:
# Count smaller than 1: 0 (0.00%)
# Count smaller than 3: 0 (0.00%)
# Count smaller than 5: 0 (0.00%)
# Count smaller than 10: 0 (0.00%)

# %% [markdown]
# # 2. Uniqueness

# %%
# %cd
# Out:
# /home/gyubin
# /home/gyubin/anaconda3/envs/EasyEdit/lib/python3.9/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /home/gyubin/anaconda3/envs/EasyEdit/lib/python3.9/site-packages/IPython/core/magics/osm.py:428: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd


df_sbj = pd.read_excel('./Knowledge_Editing_Dataset/data/one_hop/df_sbj_full_rel++.xlsx')
df_obj_true = pd.read_excel('./Knowledge_Editing_Dataset/data/one_hop/df_obj_true_full_rel++.xlsx')
df_obj_new = pd.read_excel('./Knowledge_Editing_Dataset/data/one_hop/df_obj_new_full_rel++.xlsx')

# %%
total_count = 0
sbj_count = 0
obj_true_count = 0
obj_new_count = 0
for i in range(len(df_sbj)):
    try:
        num = len(df_sbj.loc[i, 'one_hop'].split(','))
        total_count += num
        sbj_count += num
    except:
        pass
    try:
        num = len(df_obj_true.loc[i, 'obj_one_hop'].split(','))
        total_count += num
        obj_true_count += num
    except:
        pass
    try:
        num = len(df_obj_new.loc[i, 'obj_new_one_hop'].split(','))
        total_count += num
        obj_new_count += num
    except:
        pass
print(f"Total count: {total_count}")
print(f"Subject count : {sbj_count}")
print(f"Obj_true count: {obj_true_count}")
print(f"Obj_new count: {obj_new_count}")
# Out:
# Total count: 13053438
# Subject count : 1313567
# Obj_true count: 5909926
# Obj_new count: 5829945

# %%
i=0
print(df_sbj.loc[i, 'subject'])
print(df_sbj.loc[i, 'one_hop'])
# Out:
# Danielle Darrieux
# Darrieux,Obálky knih,ola2002159092,Q18040452,406072,Danielle Darrieux,XX4580778,097152196,99003663,n2009093931,37342,celebrity/danielle_darrieux,768/000092492,123,50018147,00000003388,0021527,872662,Danielle Yvonne Marie Antoinette Darrieux,302153,00064968,a0000003601717,person/danielle-darrieux,91856,I00371355,000587083,370289,46983,p17063,1931-01-01T00:00:00Z,2010-01-01T00:00:00Z,1.64,223112,82883,Danielle-darrieux,240317,10599,17880,6000000021702418818,19583,13363,25390,people/danielle-darrieux,8a51faf8a34445d081a15de657f44bc3,Darrieux-1,44418,02-A003155459,2048,n0001186,3258979,42624,danielle-darrieux,13622,18928,1397375,w66409d5,146075,87097990506579,1569352,19055,7260,170800,4865,Danielle_Darrieux,4ce2b9ef3474d,61304,35960401,5610,14567,29340,2085,946,236016,Danielle-Darrieux,darrieux-danielle,63051,KAC2020L2623,2361,1048285,35562,20233,64jmwrwq39zdjgj,danielle-darrieux-20063,M00000062962,personnage/wd/115710,17264,375066,119082,7013,37059,danielle-darrieux-lyrics.html,37971,46717,French,voice,European Film Award for Best Actress,Olivier Darrieux,Category:Danielle Darrieux,Danielle Darrieux filmography,Molière Award for Best Actress,César Award,Porfirio Rubirosa,http://commons.wikimedia.org/wiki/Special:FilePath/Danielle%20Darrieux%20Five%20Fingers%202.jpg,0000000121040114,117444333,120051397,n86138439,12530970k,034566562,DA13239992,nm0201638,35225748,b01319ec-5fbf-48ad-b208-6a338f7338be,http://commons.wikimedia.org/wiki/Special:FilePath/LL-Q150%20%28fra%29-Exilexi-Danielle%20Darrieux.wav,184411411,1917-05-01T00:00:00Z,2017-10-17T00:00:00Z,/m/04r89g,9810655595705606,2592,3890729,000217258,LNB:BCTF;=xs,agent/base/152353,12648,5944,p=danielle;n=darrieux,13945,darrieuxd,152925,ncf12117080,987007427008705171,1072,2507,40710,a/044efe0a-fca9-4cef-81c3-f3d4271930c3,Tzggy-helT9N,256191160,173630,1144,daniel_dare,181444,01410/eu_d_0225/d0225,daniel-dare,E39PBJB4hWrPYkGHbVx3wxWhpP,danielle-darrieux-en9iv7h9,29236,1140563741747467648,7_p-yNOBb,danielle-darrieux-5213,37303,160418212,27254046,singer,actor,Bois-le-Roi,film,Henri Decoin,film actor,France,human,theatre,stage actor,Bordeaux,Marie-Louise Darrieux,female,Officer of Arts and Letters,falling from height,Georges Mitsinkides,SAPA Foundation, Swiss Archive of the Performing Arts,Cemetery of Marnes-la-Coquette,Commander of the Legion of Honour,Honorary César,Silver Bear for Outstanding Artistic Contribution

# %%
# %cd Knowledge_Editing_Dataset/data/one_hop
# Out:
# /home/gyubin/Knowledge_Editing_Dataset/data/one_hop
# /home/gyubin/anaconda3/envs/EasyEdit/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
df_sbj.head(10)
# Out:
#    Unnamed: 0  index                          subject subject_id  \
# 0           0      0                Danielle Darrieux    Q234149
# 1           1      1             Edwin of Northumbria    Q348955
# 2           2      2                      Toko Yasuda   Q7813654
# 3           3      3  Autonomous University of Madrid    Q788091
# 4           4      4                             Lyon   Q6709677
# 5           5      5         Thomas Joannes Stieltjes    Q510916
# 6           6      6                   Anaal Nathrakh    Q483140
# 7           7      7                         Apple A5    Q420764
# 8           8      8                       Wellington     Q23661
# 9           9      9                   Shree Pundalik   Q7503512
#
#                                              one_hop
# 0  Darrieux,Obálky knih,ola2002159092,Q18040452,4...
# 1  Æthelburh of Kent,http://commons.wikimedia.org...
# 2  rock music,Blonde Redhead,http://commons.wikim...
# 3  http://commons.wikimedia.org/wiki/Special:File...
# 4  http://commons.wikimedia.org/wiki/Special:File...
# 5  Kingdom of the Netherlands,Jean Gaston Darboux...
# 6  black metal,Earache Records,Season of Mist,Tem...
# 7  iPad 2,iPod Touch 5,iPhone 4S,Apple Silicon,ht...
# 8  Encyclopædia Britannica 11th edition,Ottův slo...
# 9  http://commons.wikimedia.org/wiki/Special:File...

# %%
from collections import Counter
frequency_sbj = []
for i in range(len(df_sbj)):
    try:
        for word in (df_sbj.loc[i, 'one_hop'].split(',')):
            frequency_sbj.append(word)
    except:
        pass
counter_sbj = Counter(frequency_sbj)
# with open("subject_one_hop_frequency_full.txt", 'w') as f:
#     for key, value in counter_sbj.most_common():
#         f.write(f'{key}: {value}\n')

# %%
df_obj_true.head(10)
# Out:
#    index           obj obj_id  \
# 0      0        French   Q150
# 1      1  Christianity  Q5043
# 2      2        guitar  Q6607
# 3      3         Spain    Q29
# 4      4        Beirut  Q3820
# 5      5         Dutch  Q7411
# 6      6    Birmingham  Q2256
# 7      7         Apple   Q312
# 8      8        Sydney  Q3130
# 9      9         India   Q668
#
#                                          obj_one_hop
# 0  Province of Namur,present tense,history of Fre...
# 1  outline of Christianity,Portal:Christianity,mo...
# 2  mahogany wood,Instrument of the Year,http://co...
# 3  Supreme Court of Spain,Romani people,Valencian...
# 4  1973 Israeli raid on Lebanon,Siege of Beirut,E...
# 5  present tense,Low Franconian,Encyclopædia Brit...
# 6  Category:Burials in Birmingham, West Midlands,...
# 7  peripheral,SchemaSoft,Braeburn Capital,Stanfor...
# 8  2000 Summer Olympics,Category:Deaths in Sydney...
# 9  Ladakh,.భారత్,Droupadi Murmu,Madhya Pradesh,.ب...

# %%
from collections import Counter
frequency_obj = []
for i in range(len(df_obj_true)):
    try:
        for word in (df_obj_true.loc[i, 'obj_one_hop'].split(',')):
            frequency_obj.append(word)
    except:
        pass
counter_obj = Counter(frequency_obj)
# with open("object_true_one_hop_frequency_full.txt", 'w') as f:
#     for key, value in counter_obj.most_common():
#         f.write(f'{key}: {value}\n')

# %%
df_obj_new.head(10)
# Out:
#    index           obj  obj_id  \
# 0      0       English   Q1860
# 1      1         Islam    Q432
# 2      2         piano   Q5994
# 3      3        Sweden     Q34
# 4      4        Manila   Q1461
# 5      5       English   Q1860
# 6      6  Philadelphia   Q1345
# 7      7        Google     Q95
# 8      8     Sheffield  Q42448
# 9      9        Sweden     Q34
#
#                                      obj_new_one_hop
# 0  Malta,Bahrain,Vanuatu,Israel,Sierra Leone,Unit...
# 1  zakāt,Arabian mythology,Battle of Badr,Muslim ...
# 2  http://commons.wikimedia.org/wiki/Special:File...
# 3  Universal Postal Union,Organization for Securi...
# 4  Caloocan,Quezon City,megacity,Honey Lacuna,htt...
# 5  Malta,Bahrain,Vanuatu,Israel,Sierra Leone,Unit...
# 6  Upper Darby Township,Philadelphia County,Haver...
# 7  Boston Dynamics,Postini,Kaltix Corp.,DoubleCli...
# 8  Category:Births in Sheffield,Desktop Encyclope...
# 9  Universal Postal Union,Organization for Securi...

# %%
from collections import Counter
frequency_obj_new = []
for i in range(len(df_obj_new)):
    try:
        for word in (df_obj_new.loc[i, 'obj_new_one_hop'].split(',')):
            frequency_obj_new.append(word)
    except:
        pass
counter_obj_new = Counter(frequency_obj_new)
# with open("object_new_one_hop_frequency_full.txt", 'w') as f:
#     for key, value in counter_obj_new.most_common():
#         f.write(f'{key}: {value}\n')

# %%
def sort_one_hop(df, column, counter, idx, rank=3, min_count=1):
    new_dict = dict()
    for word in df.loc[idx, column].split(','):
        if counter[word] >= min_count:  # 빈도수가 min_count 이상인 경우에만 추가
            new_dict[word] = counter[word]
    new_dict = dict(sorted(new_dict.items(), key=lambda item: item[1], reverse = False))
    new_list = list(new_dict.keys())
    return new_list[:rank]

rank = 20
sort_one_hop(df_obj_true, 'obj_one_hop', counter_obj, 3, rank, min_count = 100)
# Out:
# ['Valencian Community',
#  'non-denominational',
#  '7.2',
#  '225',
#  '64',
#  '214',
#  '1412',
#  '7.1',
#  '386',
#  'municipality of Spain',
#  '82',
#  'Catalonia',
#  '295',
#  '4021',
#  'Central American Bank for Economic Integration',
#  '724',
#  'Community of Madrid',
#  'Mediterranean country',
#  '6.9',
#  '2924']

# %%
import re

def sort_one_hop(df, column, counter, idx, rank=3, min_count=1):
    stop_words = ['http', 'html', 'xml', 'jpg', 'jpeg', 'png', '/', '-', '_']
    obj = df.loc[idx, 'obj']
    print(f'object is {obj}')
    new_dict = dict()
    for word in df.loc[idx, column].split(','):
        # if any(stop_word in word for stop_word in stop_words) or not (re.search(r'[a-zA-Z]', word)):
        #     continue
        if re.search(r'^[a-zA-Z\s]+$', word) and counter[word] >= min_count:  # 빈도수가 min_count 이상인 경우에만 추가
            new_dict[word] = counter[word]
    new_dict = dict(sorted(new_dict.items(), key=lambda item: item[1], reverse = False))
    new_list = list(new_dict.keys())
    return new_list[:rank]

idx = 1
rank = 30
sort_one_hop(df_obj_true, 'obj_one_hop', counter_obj, idx, rank, min_count = 1)
# Out:
# object is Christianity
# ['outline of Christianity',
#  'christianity',
#  'christianisme',
#  'kristendom',
#  'cristianesimo',
#  'christentum',
#  'Christentum',
#  'hiristiyanlik',
#  'Christian',
#  'history of Christianity',
#  'WikiProject Christianity',
#  'hristiyanlik',
#  'Christendom',
#  'Cristianesimo',
#  'Christ',
#  'Christian denomination',
#  'Christian movement',
#  'Nazareth',
#  'Eastern Christianity',
#  'Bible',
#  'Christian denominational family',
#  'Jesus',
#  'Western Christianity',
#  'monotheism',
#  'Abrahamic religion',
#  'major religion',
#  'Judaism',
#  'Jerusalem',
#  'Christianity',
#  'worldwide']

# %%
full10_list = []
for i in range(len(df_sbj)):
    idx = i
    rank = 10
    try:
        z= sort_one_hop(df_sbj, 'one_hop', counter_sbj, idx, rank)
        x= sort_one_hop(df_obj_true, 'obj_one_hop', counter_obj, idx, rank)
        c =sort_one_hop(df_obj_new, 'obj_new_one_hop', counter_obj_new, idx, rank)
        if len(z)+len(x)+len(c) == rank*3:
            full10_list.append([idx, z, x, c])

            
    except:
        pass
    
    # try:
    #     x= sort_one_hop(df_obj_true, 'obj_one_hop', counter_sbj, idx, rank)
print(len(full10_list))
print(len(df_sbj))
# Out:
# 20424
# 21919

# %%
print(full10_list[0][1])
sbj_train = [full10_list[0][1][i] for i in [0,2,4,6,8]]
sbj_test = [full10_list[0][1][i] for i in [1,3,5,7,9]]
print(sbj_train)
print(sbj_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(full10_list[0][1])
#       2 sbj_train = [full10_list[0][1][i] for i in [0,2,4,6,8]]
#       3 sbj_test = [full10_list[0][1][i] for i in [1,3,5,7,9]]
#
# NameError: name 'full10_list' is not defined

# %% [markdown]
# # 따로저장

# %%
# %cd ../../EasyEdit/data/counterfact
# Out:
# /home/gyubin/Knowledge_Editing_Dataset/EasyEdit/data/counterfact
# /home/gyubin/anaconda3/envs/EasyEdit/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import json

file_path1 = 'counterfact-edit.json'
file_path2 = 'counterfact-train.json'
file_path3 = 'counterfact-val.json'

with open(file_path1, 'r') as file:
    data1 = json.load(file)
    print(len(data1))
with open(file_path2, 'r') as file:
    data2 = json.load(file)
    print(len(data2))
with open(file_path3, 'r') as file:
    data3 = json.load(file)
    print(len(data3))
full_data = data1 + data2 + data3
print(len(full_data))
# Out:
# 10000
# 10000
# 1919
# 21919

# %%
sorted_full_data = sorted(full_data, key=lambda x: x['case_id'])

# %%
answer = []
for data in full10_list:
    idx = data[0]
    tup = sorted_full_data[idx]
    tup['sbj_hop_train'] = [data[1][i]for i in [0,2,4,6,8]]
    tup['sbj_hop_test'] = [data[1][i]for i in [1,3,5,7,9]]
    tup['obj_true_hop_train'] = [data[2][i]for i in [0,2,4,6,8]]
    tup['obj_true_hop_test'] = [data[2][i]for i in [1,3,5,7,9]]
    tup['obj_new_hop_train'] = [data[3][i]for i in [0,2,4,6,8]]
    tup['obj_new_hop_test'] = [data[3][i]for i in [1,3,5,7,9]]
    answer.append(tup)

# %%
answer[:5]
# Out:
# [{'case_id': 0,
#   'prompt': 'The mother tongue of Danielle Darrieux is',
#   'target_new': 'English',
#   'subject': 'Danielle Darrieux',
#   'ground_truth': 'French',
#   'rephrase_prompt': 'Where Danielle Darrieux is from, people speak the language of',
#   'locality_prompt': 'Michel Rocard is a native speaker of',
#   'locality_ground_truth': 'French',
#   'sbj_hop_train': ['Bois-le-Roi', 'film', 'stage actor', 'voice', 'actor'],
#   'sbj_hop_test': ['Bordeaux', 'theatre', 'singer', 'film actor', 'France'],
#   'obj_true_hop_train': ['Overseas France',
#    'Mauritania',
#    'Andorra',
#    'Jersey',
#    'Burkina Faso'],
#   'obj_true_hop_test': ['Togo', 'Vanuatu', 'Ivory Coast', 'Chad', 'Gabon'],
#   'obj_new_hop_train': ['British Virgin Islands',
#    'United States Virgin Islands',
#    ' Ascension and Tristan da Cunha',
#    'British Indian Ocean Territory',
#    'Sint Maarten'],
#   'obj_new_hop_test': ['Turks and Caicos Islands',
#    'Saint Helena',
#    'Montserrat',
#    'Saint-Martin',
#    'Anguilla']},
#  {'case_id': 3,
#   'prompt': 'Autonomous University of Madrid, which is located in',
#   'target_new': 'Sweden',
#   'subject': 'Autonomous University of Madrid',
#   'ground_truth': 'Spain',
#   'rephrase_prompt': 'and Sallie Beavers Riley. Autonomous University of Madrid is located in',
#   'locality_prompt': 'Biure, which is located in',
#   'locality_ground_truth': 'Spain',
#   'sbj_hop_train': ['YERUN',
#    'European Alliance for Social Sciences and Humanities',
#    'Spanish Association of University Presses',
#    'Agence universitaire de la Francophonie',
#    'Madrid'],
#   'sbj_hop_test': ['Alliance 4 Universities',
#    'Conference of Rectors of Spanish Universities',
#    'Coalition for Advancing Research Assessment',
#    'European University Association',
#    'Spain'],
#   'obj_true_hop_train': ['member states of the Organization of Ibero-American States',
#    'Hispania',
#    'Organisation for Joint Armament Cooperation',
#    'United Nations Security Council',
#    'European Southern Observatory'],
#   'obj_true_hop_test': ['Organization of Ibero-American States',
#    'Central American Bank for Economic Integration',
#    'European Air Transport Command',
#    'League of Nations',
#    'European Space Agency'],
#   'obj_new_hop_train': ['Kalmar Union',
#    'Union between Sweden and Norway',
#    'Barents Euro-Arctic Council',
#    'Council of the Baltic Sea States',
#    'European Free Trade Association'],
#   'obj_new_hop_test': ['Swedes',
#    'Partnership for Peace',
#    'Nordic Council',
#    'Nordic Battle Group',
#    'European Payments Union']},
#  {'case_id': 5,
#   'prompt': 'The mother tongue of Thomas Joannes Stieltjes is',
#   'target_new': 'English',
#   'subject': 'Thomas Joannes Stieltjes',
#   'ground_truth': 'Dutch',
#   'rephrase_prompt': 'Thomas Joannes Stieltjes was born in',
#   'locality_prompt': 'Arend Lijphart is a native speaker of',
#   'locality_ground_truth': 'Dutch',
#   'sbj_hop_train': ['Faculté des sciences de Toulouse',
#    'Delft University of Technology',
#    'Royal Netherlands Academy of Arts and Sciences',
#    'Kingdom of the Netherlands',
#    'Dutch'],
#   'sbj_hop_test': ['Zwolle',
#    'Toulouse',
#    'Russian Academy of Sciences',
#    'mathematician',
#    'university teacher'],
#   'obj_true_hop_train': ['Low Countries',
#    'Sint Maarten',
#    'theodisk',
#    'Suriname',
#    'Netherlands'],
#   'obj_true_hop_test': ['Curaçao',
#    'Caribbean Netherlands',
#    'Aruba',
#    'Kingdom of the Netherlands',
#    'Belgium'],
#   'obj_new_hop_train': ['British Virgin Islands',
#    'United States Virgin Islands',
#    ' Ascension and Tristan da Cunha',
#    'British Indian Ocean Territory',
#    'Sint Maarten'],
#   'obj_new_hop_test': ['Turks and Caicos Islands',
#    'Saint Helena',
#    'Montserrat',
#    'Saint-Martin',
#    'Anguilla']},
#  {'case_id': 30,
#   'prompt': 'Leonardo Balada found employment in',
#   'target_new': 'Paris',
#   'subject': 'Leonardo Balada',
#   'ground_truth': 'Pittsburgh',
#   'rephrase_prompt': 'To get to work every day, Leonardo Balada has to',
#   'locality_prompt': 'Pierre Bonnard used to work in',
#   'locality_ground_truth': 'Pittsburgh',
#   'sbj_hop_train': ['Generación del 51',
#    'Carnegie Mellon University',
#    'Pittsburgh',
#    'librettist',
#    'musicologist'],
#   'sbj_hop_test': ['Sant Just Desvern',
#    'sardana',
#    'symphony',
#    'Catalan',
#    'Barcelona'],
#   'obj_true_hop_train': ['Misgav Regional Council',
#    'Allegheny County',
#    'Ōmiya',
#    'Novokuznetsk',
#    ' 1st Earl of Chatham'],
#   'obj_true_hop_test': ['Naucalpan de Juárez delegation',
#    'San Isidro',
#    'Saitama',
#    'William Pitt',
#    'Prešov'],
#   'obj_new_hop_train': ['Parisii',
#    'Grand Paris',
#    'C40 Cities Climate Leadership Group',
#    'League of Historical Cities',
#    'Europe'],
#   'obj_new_hop_test': ['arrondissement of Paris',
#    'Île-de-France',
#    'Kingdom of France',
#    'World Tourism Cities Federation',
#    'Rome']},
#  {'case_id': 34,
#   'prompt': 'Laurent Cars was employed in',
#   'target_new': 'Philadelphia',
#   'subject': 'Laurent Cars',
#   'ground_truth': 'Paris',
#   'rephrase_prompt': "Laurent Cars's work office is surrounded by",
#   'locality_prompt': 'Henri Matisse used to work in',
#   'locality_ground_truth': 'Paris',
#   'sbj_hop_train': ['Académie royale de peinture et de sculpture',
#    'printer',
#    'Lyon',
#    'painter',
#    'France'],
#   'sbj_hop_test': ['copper engraver', 'portrait', 'drawer', 'Paris', 'French'],
#   'obj_true_hop_train': ['Parisii',
#    'Grand Paris',
#    'C40 Cities Climate Leadership Group',
#    'League of Historical Cities',
#    'Europe'],
#   'obj_true_hop_test': ['arrondissement of Paris',
#    'Île-de-France',
#    'Kingdom of France',
#    'World Tourism Cities Federation',
#    'Rome'],
#   'obj_new_hop_train': ['Mosul',
#    'Philadelphia County',
#    'Douala',
#    'Kobe',
#    'Salvador'],
#   'obj_new_hop_test': ['Abruzzo',
#    'Nizhny Novgorod',
#    'Aix-en-Provence',
#    'Toruń',
#    'Tianjin']}]

# %%
import json

with open('counterfact-hop10.json', 'w', encoding='utf-8') as json_file:
    json.dump(answer, json_file, ensure_ascii=False, indent = 4)
